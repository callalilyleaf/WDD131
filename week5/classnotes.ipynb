# %%
# 2/5 Class notes

# %%
function addStars(span) {
    const starLength = span.innerText.length;
    span.setAttribute('aria-label', `${starLength} out of 5 stars`);

}

const spans = document.querySelectorAll('.star');
// span not['aria-label']

// for(i = 0; i < spans.length; i++){
//      addStars(i);
// }

// In the real-life production, you'd like to reuse the entire function with the const spans, 
// to load all the elements when user hits 'load more'
