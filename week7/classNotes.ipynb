# %% [markdown]
# # Class Notes of Regex, Form

# %%
const regex = /^\d{16}$/;   // ^: start of the string; \d: digits; {16}: for 16 chars; $: end of the string; //: the regex wrapper in JS
const name = /smith/i;      // i: case-'i'nsensitive
const creditCardNum = /^([3-5]5 | [1-5]0)\d{14}$/;  // start with num 3-5 following by 5 or start with num 1-5 following by 0, then have 14 digits and that's the end of the string
